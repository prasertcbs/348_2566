# %% [markdown]
# # experimenting with for loop

# %% [markdown]
# `pip install -U numpy matplotlib`

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set up the figure and subplot
fig, ax = plt.subplots()

# Create a list of points for the curve of the heart
t = np.linspace(0, 2 * np.pi, 100)
x = 16 * np.sin(t) ** 3
y = 13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t)
points = np.array([x, y]).T

# Plot the curve of the heart
plt.plot(x, y, color='r', linewidth=2)

# Fill in the heart with the color red
plt.fill(x, y, color='r', alpha=0.5)

# Display the plot
plt.axis('equal')
plt.show()

# %% [markdown]
# ## pip
#
# ```
# pip install -U jupyterlab
# pip install -U numpy pandas
# pip install -U plotly-express
# ```

# %%
import numpy as np
import plotly.express as px

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.linspace(0, 10, 5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
for n in range(0, 10, 2):
    print(n)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
np.linspace(0, 2 * np.pi, 360)
# Out:
# array([0.        , 0.01750191, 0.03500382, 0.05250573, 0.07000764,
#        0.08750954, 0.10501145, 0.12251336, 0.14001527, 0.15751718,
#        0.17501909, 0.192521  , 0.21002291, 0.22752482, 0.24502673,
#        0.26252863, 0.28003054, 0.29753245, 0.31503436, 0.33253627,
#        0.35003818, 0.36754009, 0.385042  , 0.40254391, 0.42004581,
#        0.43754772, 0.45504963, 0.47255154, 0.49005345, 0.50755536,
#        0.52505727, 0.54255918, 0.56006109, 0.57756299, 0.5950649 ,
#        0.61256681, 0.63006872, 0.64757063, 0.66507254, 0.68257445,
#        0.70007636, 0.71757827, 0.73508018, 0.75258208, 0.77008399,
#        0.7875859 , 0.80508781, 0.82258972, 0.84009163, 0.85759354,
#        0.87509545, 0.89259736, 0.91009926, 0.92760117, 0.94510308,
#        0.96260499, 0.9801069 , 0.99760881, 1.01511072, 1.03261263,
#        1.05011454, 1.06761644, 1.08511835, 1.10262026, 1.12012217,
#        1.13762408, 1.15512599, 1.1726279 , 1.19012981, 1.20763172,
# ...

# %%
import math


def heart():
    # http://mathworld.wolfram.com/HeartCurve.html
    t = np.linspace(0, 2 * np.pi, 360)
    # print(t)
    # x=[]
    # y=[]
    # for theta in t:
    #     x.append(16 * math.sin(theta) ** 3)
    #     y.append(13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t))
    x = 16 * np.sin(t) ** 3  # ufunc -> universal function
    y = 13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t)
    # return px.scatter(x=x, y=y)
    fig = px.scatter(x=x, y=y, width=600)
    for _ in range(14):
        fig.add_scatter(
            x=(x + np.random.randint(10, 70)) * np.random.randint(50, 201) / 100,
            y=y + np.random.randint(5, 30) * np.random.randint(50, 201) / 100,
        )
    # fig.add_scatter(x=x + 50, y=y)
    # fig.add_scatter(x=x + 20, y=y)
    # fig.add_scatter(x=x + 20, y=y+ 40)
    # fig.update_layout(showlegend=False)
    return fig


heart()

# %%
import numpy as np
import plotly.express as px
import random


def heart():
    # http://mathworld.wolfram.com/HeartCurve.html
    t = np.linspace(0, 2 * np.pi, 360)
    # print(t)
    x = 16 * np.sin(t) ** 3
    y = 13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t)
    # return px.scatter(x=x, y=y)
    fig = px.scatter(x=x, y=y, width=900, height=900)
    for _ in range(10):
        fig.add_scatter(
            x=(x + random.randrange(5, 30)) * random.randrange(10, 200) / 100,
            y=(y + random.randrange(5, 30)) * random.randrange(10, 200) / 100,
        )
        # fig.add_scatter(x=x + 20, y=y)
    fig.update_layout(showlegend=False)
    return fig


heart()
